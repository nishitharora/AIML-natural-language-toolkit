# %% [markdown]
# ##Natural Language Toolkit(NLTK)

# %% [markdown]
# Natural Language Toolkit is the most popular collection of libraries and programs to do NLP. http://www.nltk.org/book/

# %% [markdown]
# ### Using NLTK

# %%
import nltk
nltk.__version__
# Out:
# '3.8.1'

# %%
#import stopwords to this colab file
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
engWordsList = stopwords.words('english')

# %%
print( len(engWordsList) )
print(engWordsList)
# Out:
# 179
# ...

# %%
#hindi works in nltk
#import indian hindi words
nltk.download('indian')
# Out:
# [nltk_data] Downloading package indian to /root/nltk_data...
# [nltk_data]   Unzipping corpora/indian.zip.
# True

# %%
hindiList = nltk.corpus.indian.words('hindi.pos')
print(len(hindiList), hindiList[:50])
# Out:
# 9408 ['पूर्ण', 'प्रतिबंध', 'हटाओ', ':', 'इराक', 'संयुक्त', 'राष्ट्र', '।', 'इराक', 'के', 'विदेश', 'मंत्री', 'ने', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'का', 'मजाक', 'उड़ाया', 'है', ',', 'जिसमें', 'अमरीका', 'ने', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'को', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'है', '।', 'विदेश', 'मंत्री', 'का', 'कहना', 'है', 'कि', 'चूंकि', 'बगदाद']

# %%
import nltk
nltk.download('stopwordspun')
# Out:
# [nltk_data] Error loading stopwordspun: Package 'stopwordspun' not
# [nltk_data]     found in index
# False

# %% [markdown]
# ### Sentence - word tokenizer

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
#textpara = "Geneva, May 26 (PTI) Switzerland has declared May 26 as the Science Day in honour of visiting President A P J Abdul Kalam. This was announced by the Swiss government, following his arrival here last night on a four-day state visit, considering his vast expertise in science and technology. Switzerland considers the President as the father of India missile programme. Kalam is the first Indian head of state visiting Switzerland after a gap of more than 30 years. Former President V V Giri's was the last high profile visit to the country."
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
aboutKalam="He was a crucial Mr. figure in India’s ‘Porkhran-II’ nuclear tests.  Which took place in May 1998. Kalam became a national hero due to the success of these nuclear tests.  His popularity skyrocketed."
aboutKalam += " As a Professor, He became a visiting professor at the ‘Indian Institute of Management (IIM), Ahemdabad,’ ‘Indian Institute of Management ((IIM), Indore,’ and the ‘Indian Institute of Management (IIM), Shillong,’ after his presidential term ended. He also taught technology at ‘Anna University,’ ‘Banaras Hindu University,’ and ‘International Institute of Information Technology (IIIT), Hyderabad.’. he was a professor of Aerospace Engineering at Anna University, as well as the chancellor of the ‘Indian Institute of Space Science and Technology Thiruvananthapuram,’ an honorary fellow of the ‘Indian Institute of Science (IISc),’ . An adjunct at several other research and academic institutes across the country."

print(aboutKalam)
kalamList = sent_tokenize( aboutKalam)
print(len(kalamList) )
for s in kalamList:
  print(s)
# Out:
# He was a crucial Wr. Figure in India’s ‘Porkhran-II’ nuclear tests.  Which took place in May 1998. Kalam became a national hero due to the success of these nuclear tests.  His popularity skyrocketed. As a Professor, He became a visiting professor at the ‘Indian Institute of Management (IIM), Ahemdabad,’ ‘Indian Institute of Management ((IIM), Indore,’ and the ‘Indian Institute of Management (IIM), Shillong,’ after his presidential term ended. He also taught technology at ‘Anna University,’ ‘Banaras Hindu University,’ and ‘International Institute of Information Technology (IIIT), Hyderabad.’. he was a professor of Aerospace Engineering at Anna University, as well as the chancellor of the ‘Indian Institute of Space Science and Technology Thiruvananthapuram,’ an honorary fellow of the ‘Indian Institute of Science (IISc),’ . An adjunct at several other research and academic institutes across the country.
# 9
# He was a crucial Wr.
# Figure in India’s ‘Porkhran-II’ nuclear tests.
# ...

# %%
aboutKapany ="As an entrepreneur and business executive, Kapany specialized in the processes of innovation and the management of technology and technology transfer. In 1960, he founded Optics Technology Inc. and was chairman of the board, President, and Director of Research for twelve years. In 1967 the company went public with numerous corporate acquisitions and joint-ventures in the United States and abroad. In 1973, Kapany founded Kaptron Inc. and was president and CEO until 1990 when he sold the company to AMP Incorporated. "
l1 = sent_tokenize(aboutKapany)
print(len(l1))
for s in l1:
  print(s)
# Out:
# 4
# As an entrepreneur and business executive, Kapany specialized in the processes of innovation and the management of technology and technology transfer.
# In 1960, he founded Optics Technology Inc. and was chairman of the board, President, and Director of Research for twelve years.
# In 1967 the company went public with numerous corporate acquisitions and joint-ventures in the United States and abroad.
# In 1973, Kapany founded Kaptron Inc. and was president and CEO until 1990 when he sold the company to AMP Incorporated.

# %%
sentList = sent_tokenize(textpara)
print(len(sentList), sentList)
for i in sentList:
  print(i)
# Out:
# 5 ['Geneva, May 26 (PTI) Switzerland has declared May 26 as the Science Day in honour of visiting President A P J Abdul Kalam.', 'This was announced by the Swiss government, following his arrival here last night on a four-day state visit, considering his vast expertise in science and technology.', 'Switzerland considers the President as the father of India missile programme.', 'Kalam is the first Indian head of state visiting Switzerland after a gap of more than 30 years.', "Former President V V Giri's was the last high profile visit to the country."]
# Geneva, May 26 (PTI) Switzerland has declared May 26 as the Science Day in honour of visiting President A P J Abdul Kalam.
# This was announced by the Swiss government, following his arrival here last night on a four-day state visit, considering his vast expertise in science and technology.
# Switzerland considers the President as the father of India missile programme.
# ...

# %%
from nltk.tokenize import word_tokenize

#print(kalamList[3])
#wordList = word_tokenize(kalamList[3])
#print(len(wordList) , wordList)
# print first element of list
print (len(l1[0]), l1[0])
print (len(word_tokenize(l1[0])))
wordList = word_tokenize(l1[0])
print (wordList)
# Out:
# 150 As an entrepreneur and business executive, Kapany specialized in the processes of innovation and the management of technology and technology transfer.
# 23
# ['As', 'an', 'entrepreneur', 'and', 'business', 'executive', ',', 'Kapany', 'specialized', 'in', 'the', 'processes', 'of', 'innovation', 'and', 'the', 'management', 'of', 'technology', 'and', 'technology', 'transfer', '.']

# %%
#stopwords in english
stopwordList = stopwords.words('english')
print(len(stopwordList))
# Out:
# 179

# %%
# from wordList remove the elements of stopwords
# two lists are avaiable
#1. total stopwords - stopwordList
#2. wordList prepared by use
filterdWords=[]
print(wordList)

for w in wordList:
  if w not in stopwordList:
    filterdWords.append(w)

print (len(wordList) , len(filterdWords))
print (filterdWords)
# Out:
# ['As', 'an', 'entrepreneur', 'and', 'business', 'executive', ',', 'Kapany', 'specialized', 'in', 'the', 'processes', 'of', 'innovation', 'and', 'the', 'management', 'of', 'technology', 'and', 'technology', 'transfer', '.']
# 23 14
# ['As', 'entrepreneur', 'business', 'executive', ',', 'Kapany', 'specialized', 'processes', 'innovation', 'management', 'technology', 'technology', 'transfer', '.']

# %% [markdown]
# ### count the stopwords in the given text

# %%
# given text is
#Ashtami, in particular, is celebrated with a great passion and fervour, especially in West Bengal. The ten-armed goddess riding the lion is highly regarded in this part of the country and even the weapons of Goddess Durga are worshipped while reciting mantras in a ritual known as Astra Puja. Ashtami marks the eighth day of the festival and on this auspicious day, devotees tend to observe rigorous fast, feast and worship for Goddess Durga who symbolizes strength. A celebration of traditional culture and customs, massive idols of Goddess Durga are installed throughout India while enormous puja pandals are set up at various places for devotees to visit and worship.
from nltk.corpus import stopwords
engWordsList = stopwords.words('english')
print(len(engWordsList), engWordsList)
# Out:
# 179 ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'th
# ...

# %%
data = "Ashtami, in particular, is celebrated with a great passion and fervour, especially in West Bengal. The ten-armed goddess riding the lion is highly regarded in this part of the country and even the weapons of Goddess Durga are worshipped while reciting mantras in a ritual known as Astra Puja. Ashtami marks the eighth day of the festival and on this auspicious day, devotees tend to observe rigorous fast, feast and worship for Goddess Durga who symbolizes strength. A celebration of traditional culture and customs, massive idols of Goddess Durga are installed throughout India while enormous puja pandals are set up at various places for devotees to visit and worship."
print(len(data))
# Out:
# 670

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
wordlist=word_tokenize(data)
print(len(wordlist),wordlist)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
for w in wordlist:
  if w.lower() not in engWordsList:
    print(w, end=" ")
# Out:
# Ashtami , particular , celebrated great passion fervour , especially West Bengal . ten-armed goddess riding lion highly regarded part country even weapons Goddess Durga worshipped reciting mantras ritual known Astra Puja . Ashtami marks eighth day festival auspicious day , devotees tend observe rigorous fast , feast worship Goddess Durga symbolizes strength . celebration traditional culture customs , massive idols Goddess Durga installed throughout India enormous puja pandals set various places devotees visit worship .

# %% [markdown]
# ### Web scrapping : URLlib module

# %%
import urllib.request
#recData = urllib.request.urlopen ('http://php.net/') https://sarwansingh.com/%e0%a8%a4%e0%a9%87%e0%a8%b0%e0%a8%be-%e0%a8%b8%e0%a8%be%e0%a8%a5-%e0%a8%9b%e0%a9%b1%e0%a8%a1-%e0%a8%9c%e0%a8%be%e0%a8%a3%e0%a8%be-%e0%a4%a4%e0%a5%87%e0%a4%b0%e0%a4%be-%e0%a4%b8%e0%a4%be%e0%a4%a5/
blogurl = "https://www.imdb.com/title/tt12062432/"
recData = urllib.request.urlopen (blogurl)
pagedata= recData.read()
print(pagedata )

#<!DOCTYPE html><html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><meta name="viewport"
# Out:
# b'<!DOCTYPE html><html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListener(\'load\', (event) => {\n        if (typeof window.csa !== \'undefined\' && typeof window.csa === \'function\') {\n            var csaLatencyPlugin = window.csa(\'Content\', {\n                element: {\n                    slotId: \'LoadTitle\',\n                    type: \'service-call\'\n                }\n            });\n            csaLatencyPlugin(\'mark\', \'clickToBodyBegin\', 1667989590183);\n        }\n    })</script><title>Galwakdi (2022) - IMDb</title><meta name="description" content="Galwakdi: Directed by Sharan Art. With Tarsem Jassar, Wamiqa Gabbi, B.N. Sharma, Raghveer Boli. Galwakdi is a Punjabi Movie that is full of Comedy and Romance with D
# ...

# %%
from bs4 import BeautifulSoup

soup=BeautifulSoup(pagedata,"html5lib")
text=soup.get_text(strip=True)
print(text)
# Out:
# if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1667989590183);
#         }
# ...

# %%
#search text within list
givenText = "Switzerland considers the President as the father of India missile programme."
search = "missile"
if search in givenText :
  print("yes")
  st= givenText.index(search)
  beg=st
  print(st)
  sp=0
  while (st>0):
    if givenText[st]==" ":
      sp= sp+1
      if sp==3:      break
    st= st-1
else :
  print ("no")
print(st)

print(givenText[st:beg] )
# Out:
# yes
# 59
# 49
#  of India

# %%
#search text within list
print(pagedata )
givenText =str(pagedata)  # "Switzerland considers the President as the father of India missile programme."
search = "Summer 6-8 weeks and Industrial Training 6 months courses"   #"Online Registration Form"
if search in givenText :
  print("yes")
  st= givenText.index(search)
  beg=st
  print(st)
  sp=0
  while (st>0):
    if givenText[st]==" ":
      sp= sp+1
      if sp==3:      break
    st= st-1
else :
  print ("no")
print(st)

print(givenText[st:beg] )
# Out:
# b'\n\n\n<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="ie6 ie" lang="en" dir="ltr"> <![endif]-->\n<!--[if IE 7]>    <html class="ie7 ie" lang="en" dir="ltr"> <![endif]-->\n<!--[if IE 8]>    <html class="ie8 ie" lang="en" dir="ltr"> <![endif]-->\n<!--[if gt IE 8]> <!--> <html class="" lang="en" dir="ltr"> <!--<![endif]-->\n<head>\n  <meta charset="utf-8" />\n<link rel="shortcut icon" href="https://www.nielit.gov.in/chandigarh/sites/default/files/nielit-fevicon.jpg" type="image/jpeg" />\n  <!-- Set the viewport width to device width for mobile -->\n  <meta name="viewport" content="width=device-width" />\n  <title>Government of India : National Institute of Electronics &amp; Information Technology</title>\n <style   media="all">\n@import url("https://www.nielit.gov.in/chandigarh/modules/system/system.base.css?qypqoc");\n@import url("https://www.nielit.gov.in/chandigarh/modules/system/system.menus.css?qypqoc");\n@import url("https://www.nielit.gov.in/chandigarh/modules/system/system.mes
# ...

# %%
# getting clean HTML file
from bs4 import BeautifulSoup
import urllib.request
sarLink = "https://sarwansingh.com"
response=urllib.request.urlopen(sarLink)
html=response.read()
soup=BeautifulSoup(html,"html5lib")
text=soup.get_text(strip=True)
print(text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-5c0800db4a6c> in <module>()
#       3 import urllib.request
#       4 sarLink = "https://sarwansingh.com"
# ----> 5 response=urllib.request.urlopen(sarLink)
#       6 html=response.read()
#       7 soup=BeautifulSoup(html,"html5lib")
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
tokens = [t for t in text.split()]
print (tokens)
# Out:
# ['Hindi', 'news,', 'हिंदी', 'न्यूज़', ',', 'Hindi', 'Samachar,', 'हिंदी', 'समाचार,', 'Latest', 'News', 'in', 'Hindi,', 'Breaking', 'News', 'in', 'Hindi,', 'ताजा', 'ख़बरें,', 'Aaj', 'Tak', 'Newsvar', 'is_sso_check=!0;var', 'ssoUserDetail;var', 'is_ad_free="no";function', 'GetQueryStringParams(sParam){var', 'sPageURL=window.location.href;var', "sURLVariables=sPageURL.split('#');for(var", 'i=0;i<sURLVariables.length;i++){var', "sParameterName=sURLVariables[i].split('=');if(sParameterName[0]==sParam){return", 'sParameterName[1]}}}', 'function', 'getLoginCookie(cname){var', 'name=cname+"=";var', "ca=document.cookie.split(';');for(var", 'i=0;i<ca.length;i++){var', "c=ca[i];while(c.charAt(0)=='", "'){c=c.substring(1)}", 'if(c.indexOf(name)==0){return', 'c.substring(name.length,c.length)}}', 'return""}(function(i,s,o,g,r,a,m){i.GoogleAnalyticsObject=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new', 'Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1
# ...

# %%
 # print the frequency distribution
 stulist= ['amit','sita','sohan','amit', 'sita','manoj','sita','manoj']
 freq  = nltk.FreqDist(stulist)
 for key, val in freq.items():
   print (key,val)
# Out:
# amit 2
# sita 3
# sohan 1
# manoj 2

# %%
freq.plot()

# %% [markdown]
# ### word stemming

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print(stemmer.stem('increses'))
print(stemmer.stem('regarding'))
print(stemmer.stem('chairs'))
# Out:
# incres
# regard
# chair

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('increases'))
print(lemmatizer.lemmatize('chairs'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# increase
# chair

# %% [markdown]
# ### web Scraping

# %% [markdown]
#  [Example from ](https://brightdata.com/blog/how-tos/how-to-use-beautiful-soup-for-web-scraping-with-python?cam=aw_blog_dynamic__547760284460&utm_term=&utm_campaign=blog&utm_source=adwords&utm_medium=ppc&utm_content=dynamic&hsa_acc=1046276282&hsa_cam=13023430270&hsa_grp=131242020607&hsa_ad=547760284460&hsa_src=g&hsa_tgt=dsa-39587879683&hsa_kw=&hsa_mt=b&hsa_net=adwords&hsa_ver=3&gclid=Cj0KCQjwtrSLBhCLARIsACh6RmjgmiL0Tcx-5GRHL9gFqqvyFT2qE-MGvLYpLSd99iiT7MoT51rIslgaAhdZEALw_wcB)

# %%
import requests
url="https://www.brainyquote.com/topics/motivational-quotes"
r = requests.get(url)
print(r.content)
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en">\n<head>\n<title>Motivational Quotes - BrainyQuote</title>\n<meta name="robots" content="all">\n<meta charset="utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, viewport-fit=cover"><meta name="description" content="Explore 274 Motivational Quotes by authors including Elon Musk, Eleanor Roosevelt, and St. Jerome at BrainyQuote.">\n<meta name="googlebot" content="NOODP">\n<meta property="ver" content="12.7.0:4565772">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="msapplication-config" content="none">\n<meta name="apple-mobile-web-app-capable" content="yes">\n<meta property="ts" content="1634348215">\n<meta property="og:site_name" content="BrainyQuote">\n<meta property="og:title" content="Motivational Quotes - BrainyQuote">\n<meta property="og:type" content="article">\n<meta property="og:description" content="Explore 274 Motivational Quotes by authors including Elon Musk, Eleanor Roosevelt, and St.
# ...

# %%
# step 2
from bs4 import BeautifulSoup
soup = BeautifulSoup( r.content, 'html5lib')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <title>Motivational Quotes - BrainyQuote</title>
# <meta content="all" name="robots"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/><meta content="Explore 274 Motivational Quotes by authors including Elon Musk, Eleanor Roosevelt, and St. Jerome at BrainyQuote." name="description"/>
# <meta content="NOODP" name="googlebot"/>
# <meta content="12.7.0:4565772" property="ver"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="none" name="msapplication-config"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="1634348215" property="ts"/>
# <meta content="BrainyQuote" property="og:site_name"/>
# <meta content="Motivational Quotes - BrainyQuote" property="og:title"/>
# <meta content="article" property="og:type"/>
# ...

# %%
table = soup.find('div', attrs={ 'id':'quotesList'})
print(table.prettify())
# Out:
# <div class="bq-mg bqcpx grid-layout-hide reflow_body bq_center ql_page" id="quotesList">
#  <div class="qbcol-c" id="qbcc">
#   <div class="qbcol qbc-spc" id="qbc1">
#    <div class="grid-item qb clearfix bqQt" id="pos_1_1">
#     <a class="b-qt qt_389605 oncl_q" href="/quotes/st_jerome_389605?src=t_motivational" title="view quote">
#      <div style="display: flex;justify-content: space-between">
#       Good, better, best. Never let it rest. 'Til your good is better and your better is best.
#       <img alt="Share this Quote" class="bq-qb-chv" src="/st/img/4565772/fa/chv-r.svg"/>
#      </div>
#     </a>
#     <a class="bq-aut qa_389605 oncl_a" href="/authors/st-jerome-quotes" title="view author">
#      St. Jerome
#     </a>
#    </div>
#    <div class="grid-item qb clearfix bqQt" id="pos_1_2">
#     <a class="b-qt qt_378967 oncl_q" href="/quotes/nelson_mandela_378967?src=t_motivational" title="view quote">
#      <div style="display: flex;justify-content: space-between">
# ...

# %%
for row in table.findAll('div', attrs ={'class':'qti-listm'}):
  quote ={}
  try:
    quote['author'] = row.img['alt'].split("-")[1]
    quote['text'] = row.img['alt'].split("-")[0]
    #quotes.append(quote)
    print(quote)
  except TypeError :
    continue
# Out:
# {'author': ' Arthur Ashe', 'text': 'Start where you are. Use what you have. Do what you can. '}
# {'author': ' William Wordsworth', 'text': 'To begin, begin. '}
# {'author': ' Benjamin Disraeli', 'text': 'Never complain and never explain. '}
# {'author': ' William James', 'text': 'Act as if what you do makes a difference. It does. '}
